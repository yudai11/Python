# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.arange(1.0, 2.5, 0.001)
u = np.arange(0, 2 * np.pi , 0.01)

t, u = np.meshgrid(t, u)
#     ax.plot_surface(x, y, z, cmap="winter")

def plot_surface2(ax, a):
    x =  a * np.cos(u) * np.sqrt(t*t-1)
    y =  a * np.sin(u) * np.sqrt(t*t-1)
    z = t
    ax.plot_surface(x, y, z, cmap="winter")

# 図の設定
# fig = plt.figure(figsize=(18, 6))
# a_values = [1, 0.5, 0]

# 各aの値に対してサブプロットを作成
plot_surface2(ax, 1)

ax.view_init(elev=30, azim=150)

plt.savefig("hypb_1.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.arange(-0.1, 3.0, 0.001)
u = np.arange(0, 2 * np.pi , 0.01)

t, u = np.meshgrid(t, u)


def plot_surface2(ax, a):
    z =  np.cos(u) * np.sinh(t)
    y =  np.sin(u) * np.sinh(t)
    x = np.cosh(t)
    ax.plot_surface(x, y, z, cmap="winter")

plot_surface2(ax, 100)

ax.view_init(elev=15, azim=140)

plt.savefig("hyp_1.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.arange(-2.0, 2.0, 0.01)
u = np.arange(-2.0, 2.0, 0.01)

t, u = np.meshgrid(t, u)


# def plot_surface2(ax, a):
#     z =  np.cos(u) * np.sinh(t)
#     y =  np.sin(u) * np.sinh(t)
#     x = np.cosh(t)
#     ax.plot_surface(0, y, z, cmap="winter")

ax.plot_surface(0, t, u, cmap="winter")

# plot_surface2(ax, 100)

ax.view_init(elev=15, azim=140)

plt.savefig("plane_1.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.arange(0, 2 * np.pi, 0.005)
u = np.arange(0, 2 * np.pi , 0.005)

t, u = np.meshgrid(t, u)


def plot_surface2(ax, a):
    z =  np.cos(u) * np.sin(t)
    y =  np.sin(u) * np.sin(t)
    x = np.cos(t)
    ax.plot_surface(x, y, z, cmap="winter")

plot_surface2(ax, 100)

ax.view_init(elev=15, azim=140)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.set_zticks([])
ax.set_box_aspect([1,1,0.9])  # アスペクト比を均等に設定
# ax.set_axis_off()

plt.savefig("sph_1.png")
plt.show()
