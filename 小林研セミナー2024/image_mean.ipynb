# %%
# !pip install opencv-python
# !pip install torchvision

# %%
# パッケージのimport
import os
import urllib.request
import zipfile
import numpy as np
import json
from PIL import Image
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# 画像ファイルを開く
imagel = "証明写真左.jpeg"
imager = "証明写真右.jpeg"
output_image = "image_gray.png"



# 画像を読み込み
# 画像をグレースケールに変換
imgl = Image.open(imagel)
imgr = Image.open(imager)

# 読み込んだ画像の幅、高さを取得し半分に
(width, height) = (500, 500)
# 画像をリサイズする
imgl= imgl.resize((width, height))
imgr= imgr.resize((width, height))
imgl.save("face_left.png")
imgr.save("face_right.png")
imgr

mask = Image.new("L", imgl.size, 128)
img3 = Image.composite(imgl, imgr, mask)
img3.save("face_comp.png")
img3
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# 画像ファイルを開く
imagel = "証明写真真ん中.jpeg"

output_image = "face_centor.png"



# 画像を読み込み
# 画像をグレースケールに変換
imgl = Image.open(imagel)

# 読み込んだ画像の幅、高さを取得し半分に
(width, height) = (500, 500)
# 画像をリサイズする
imgl= imgl.resize((width, height))
imgl.save("face_cent.png")
imgl
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# 画像ファイルを開く
imagel = "証明写真左.jpeg"
imager = "証明写真右.jpeg"
output_image = "image_gray.png"



# 画像を読み込み
# 画像をグレースケールに変換
imgl = Image.open(imagel).convert("L")
imgr = Image.open(imager).convert("L")

# グレースケール画像を保存
# img.save(output_image)


img_array = np.array(img)

# 画像サイズ取得
height, width = imgl.shape

# x, y 軸の座標を作成
xl = np.linspace(0, width, width)
yl = np.linspace(0, height, height)

# 画像サイズ取得
height, width = imgr.shape

# x, y 軸の座標を作成
xr = np.linspace(0, width, width)
yr = np.linspace(0, height, height)


xr, yr = np.meshgrid(xr, yr)

# 3Dプロット作成
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(elev=60, azim=120)


# 濃淡（輝度値）を高さとしてプロット
ax.plot_surface(x, y, img_array, cmap='gray')

# 軸ラベル設定
ax.set_xlabel("Width")
ax.set_ylabel("Height")
ax.set_zlabel("Intensity")

# プロット表示
plt.savefig("gray_3d.png")
plt.show()
# Out:
#   Cell In[30], line 36
#     x = (xl + )
#               ^
# SyntaxError: invalid syntax

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 画像を読み込む
img = cv2.imread('証明写真右.jpeg')
cv2.imshow('Resized Image', img)

# 新しいサイズ (幅, 高さ)
new_width = 30
new_height = 20

# リサイズ処理
resized_img = cv2.resize(img, (new_width, new_height))

# リサイズされた画像を表示
cv2.imshow('Resized Image', resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[42], line 8
#       6 # 画像を読み込む
#       7 img = cv2.imread('証明写真右.jpeg')
# ----> 8 cv2.imshow('Resized Image', img)
#      10 # 新しいサイズ (幅, 高さ)
#      11 new_width = 30
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
